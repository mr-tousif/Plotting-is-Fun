# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(0,1,100)

# %%
y_1=x
y_2=x**2
y_3=x**3
y_4=x**4
y_5=x**5
y_6=x**6
y_7=x**7
y_8=x**8
y_9=x**9
y_10=x**10
y_11=x**11

y_11=x**(1/2)
y_12=x**(1/3)
y_13=x**(1/4)
y_14=x**(1/5)
y_15=x**(1/6)
y_16=x**(1/7)
y_17=x**(1/8)
y_18=x**(1/9)
y_19=x**(1/10)

# %%
plt.plot(x,y_1,"--")
plt.plot(x,y_2,"--")
plt.plot(x,y_3)
plt.plot(x,y_4)
plt.plot(x,y_5)
plt.plot(x,y_6)
plt.plot(x,y_7)
plt.plot(x,y_8)
plt.plot(x,y_9)
plt.plot(x,y_10,"ro-")

plt.plot(x,y_11,"--")
plt.plot(x,y_12)
plt.plot(x,y_13)
plt.plot(x,y_14)
plt.plot(x,y_15)
plt.plot(x,y_16)
plt.plot(x,y_17)
plt.plot(x,y_18)
plt.plot(x,y_19,"go-")
plt.text(0.35,0.39,r"$y=x$",rotation=45,verticalalignment='center',horizontalalignment='center')
plt.text(0.34,0.53,r"$y=\sqrt[2]{x}$",verticalalignment='center',horizontalalignment='center',rotation=45)
plt.text(0.3,0.62,r"$y=\sqrt[3]{x}$",verticalalignment='center',horizontalalignment='center',rotation=45)
plt.text(0.26,0.68,r"$y=\sqrt[4]{x}$",verticalalignment='center',horizontalalignment='center',rotation=45)
plt.text(0.24,0.75,r"$y=\sqrt[5]{x}$",verticalalignment='center',horizontalalignment='center',rotation=45)
plt.text(0.22,0.80,r"$y=\sqrt[6]{x}$",verticalalignment='center',horizontalalignment='center',rotation=45)
plt.text(0.18,0.82,r"$y=\sqrt[7]{x}$",verticalalignment='center',horizontalalignment='center',rotation=45)
plt.text(0.13,0.86,r"$y=\sqrt[10]{x}$",verticalalignment='center',horizontalalignment='center',rotation=35)

plt.text(0.46,0.26,r"$y=x^2$",verticalalignment='center',horizontalalignment='center',rotation=43)
plt.text(0.55,0.20,r"$y=x^3$",verticalalignment='center',horizontalalignment='center',rotation=43)
plt.text(0.60,0.16,r"$y=x^4$",verticalalignment='center',horizontalalignment='center',rotation=45)
plt.text(0.70,0.18,r"$y=x^5$",verticalalignment='center',horizontalalignment='center',rotation=45)
plt.text(0.74,0.16,r"$y=x^6$",verticalalignment='center',horizontalalignment='center',rotation=45)
plt.text(0.79,0.14,r"$y=x^8$",verticalalignment='center',horizontalalignment='center',rotation=45)
plt.text(0.84,0.10,r"$y=x^{10}$",verticalalignment='center',horizontalalignment='center',rotation=45)
plt.xlabel(r"$x$" , fontsize=12)
plt.ylabel(r"$y=f(x)$", fontsize=12)
plt.savefig("math.png")
